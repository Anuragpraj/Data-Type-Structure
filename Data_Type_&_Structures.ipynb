# %% [markdown]
# Data Types & Structures

# %% [markdown]
# 1. What are data structures, and why are they important?
#     - Data structures are ways of organizing and storing data efficiently. They’re important because they affect performance, memory usage, and ease of solving problems.

# %% [markdown]
# 2. Explain the difference between mutable and immutable data types with examples.
#
#    - Mutable: Can be changed (e.g., list, dict, set).
#
#      Immutable: Cannot be changed (e.g., tuple, string, int).

# %% [markdown]
# 3. What are the main differences between lists and tuples in Python?
#
#    - List: Mutable, slower, uses more memory.
#
#      Tuple: Immutable, faster, memory efficient.

# %% [markdown]
# 4. Describe how dictionaries store data.
#    - Dictionaries store data as key-value pairs using a hash table for fast lookups.

# %% [markdown]
# 5. Why might you use a set instead of a list in Python?
#    - Sets automatically remove duplicates and allow fast membership testing.

# %% [markdown]
# 6. What is a string in Python, and how is it different from a list?
#    - A string is an immutable sequence of characters, while a list is a mutable sequence of elements (can hold mixed types).

# %% [markdown]
# 7. How do tuples ensure data integrity in Python?
#     - Tuples are immutable, so their contents can’t be changed accidentally, preserving integrity.

# %% [markdown]
# 8. What is a hash table, and how does it relate to dictionaries in Python?
#    - A hash table maps keys to values using a hash function. Python dictionaries are implemented using hash tables.

# %% [markdown]
# 9. Can lists contain different data types in Python?
#    - Yes, lists can hold mixed data types (e.g., [1, "hello", 3.14]).

# %% [markdown]
# 10. Explain why strings are immutable in Python.
#     - Strings are immutable to ensure security, memory efficiency (reusability), and thread-safety.

# %% [markdown]
# 11. What advantages do dictionaries offer over lists for certain tasks?
#     - Dictionaries allow fast key-based lookups, whereas lists require sequential searches.

# %% [markdown]
# 12. Describe a scenario where using a tuple would be preferable over a list.
#     - When storing fixed data like GPS coordinates (28.6, 77.2) or database keys that should not change.

# %% [markdown]
# 13. How do sets handle duplicate values in Python?
#     - Sets automatically remove duplicates—only unique values are stored.

# %% [markdown]
# 14. How does the "in" keyword work differently for lists and dictionaries?
#
#     - List: Checks if a value exists.
#
#       Dictionary: Checks if a key exists (not the value).

# %% [markdown]
# 15. Can you modify the elements of a tuple? Explain why or why not.
#     - No, tuples are immutable—once created, elements can’t be changed.

# %% [markdown]
# 16. What is a nested dictionary, and give an example of its use case?
#     - A dictionary inside another dictionary.
# Example: students = {"A": {"age": 20, "grade": "A"}} → useful for structured data.

# %% [markdown]
# 17. Describe the time complexity of accessing elements in a dictionary.
#     - On average O(1) (constant time) due to hashing.

# %% [markdown]
# 18. In what situations are lists preferred over dictionaries?
#     - When order matters, data is sequential, or you don’t need key-value mapping.

# %% [markdown]
# 19. Why are dictionaries considered unordered, and how does that affect data retrieval?
#     - Before Python 3.7, dictionaries didn’t maintain insertion order. Retrieval is by key, not position.

# %% [markdown]
# 20. Explain the difference between a list and a dictionary in terms of data retrieval.
#
#     - List: Retrieve by index (e.g., list[0]).
#
#       Dictionary: Retrieve by key (e.g., dict["name"]).

# %% [markdown]
# Practical Questions

# %% [markdown]
# 1. Write a code to create a string with your name and print it.

# %%
name = "Anurag"
print(name)
# Out:
# Anurag

# %% [markdown]
# 2. Write a code to find the length of the string 'Hello World".

# %%
print(len("Hello World"))
# Out:
# 11

# %% [markdown]
# 3. Write a code to slice the first 3 characters from the string "Python Programming".

# %%
s = "Python Programming"
print(s[:3])
# Out:
# Pyt

# %% [markdown]
# 4. Write a code to convert the string "hello" to uppercase.

# %%
print("hello".upper())
# Out:
# HELLO

# %% [markdown]
# 5. Write a code to replace the word "apple" with "orange" in the string like apple".

# %%
print("apple".replace("apple", "orange"))
# Out:
# orange

# %% [markdown]
# 6. Write a code to create a list with numbers 1 to 5 and print it.

# %%
lst = [1, 2, 3, 4, 5]
print(lst)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# 7. Write a code to append the number 10 to the list [1, 2, 3, 4].

# %%
lst2 = [1, 2, 3, 4]
lst2.append(10)
print(lst2)
# Out:
# [1, 2, 3, 4, 10]

# %% [markdown]
# 8. Write a code to remove the number 3 from the list (1, 2, 3, 4, 5].

# %%
lst3 = [1, 2, 3, 4, 5]
lst3.remove(3)
print(lst3)
# Out:
# [1, 2, 4, 5]

# %% [markdown]
# 9. Write a code to access the second element in the list ['a', 'b', 'c, 'd'].

# %%
letters = ['a', 'b', 'c', 'd']
print(letters[1])
# Out:
# b

# %% [markdown]
# 10. Write a code to reverse the list [10, 20, 30, 40, 50].

# %%
nums = [10, 20, 30, 40, 50]
nums.reverse()
print(nums)
# Out:
# [50, 40, 30, 20, 10]

# %% [markdown]
# 11. Write a code to create a tuple with the elements 100, 200, 300 and print it.

# %%
t = (100, 200, 300)
print(t)
# Out:
# (100, 200, 300)

# %% [markdown]
# 12. Write a code to access the second-to-last element of the tuple ('red', 'green', 'blue', 'yellow').

# %%
colors = ('red', 'green', 'blue', 'yellow')
print(colors[-2])
# Out:
# blue

# %% [markdown]
# 13. Write a code to find the minimum number in the tuple (10, 20, 5, 15),

# %%
print(min((10, 20, 5, 15)))
# Out:
# 5

# %% [markdown]
# 14. Write a code to find the index of the element "cat" in the tuple ('dog', 'cat', 'rabbit').

# %%
print(('dog', 'cat', 'rabbit').index("cat"))
# Out:
# 1

# %% [markdown]
# 15. Write a code to create a tuple containing three different fruits and check if "kiwi" is in it.

# %%
fruits = ("apple", "banana", "mango")
print("kiwi" in fruits)
# Out:
# False

# %% [markdown]
# 16. Write a code to create a set with the elements 'a', 'b, c' and print it.

# %%
st = {'a', 'b', 'c'}
print(st)
# Out:
# {'c', 'a', 'b'}

# %% [markdown]
# 17. Write a code to clear all elements from the set (1, 2, 3, 4, 5}.

# %%
st2 = {1, 2, 3, 4, 5}
st2.clear()
print(st2)
# Out:
# set()

# %% [markdown]
# 18. Write a code to remove the element 4 from the set {1, 2, 3, 4}.

# %%
st3 = {1, 2, 3, 4}
st3.remove(4)
print(st3)
# Out:
# {1, 2, 3}

# %% [markdown]
# 19. Write a code to find the union of two sets [1, 2, 3] and [3, 4, 5).

# %%
print({1, 2, 3}.union({3, 4, 5}))
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# 20. Write a code to find the intersection of two sets [1, 2, 3] and [2, 3, 4).

# %%
print({1, 2, 3}.intersection({2, 3, 4}))
# Out:
# {2, 3}

# %% [markdown]
# 21. Write a code to create a dictionary with the keys "name", "age", and "city", and print it.

# %%
d = {"name": "Anurag", "age": 22, "city": "Indore"}
print(d)
# Out:
# {'name': 'Anurag', 'age': 22, 'city': 'Indore'}

# %% [markdown]
# 22. Write a code to add a new key-value pair "country": "USA" to the dictionary ['name': 'John', 'age: 25).

# %%
d2 = {"name": "John", "age": 25}
d2["country"] = "USA"
print(d2)
# Out:
# {'name': 'John', 'age': 25, 'country': 'USA'}

# %% [markdown]
# 23. Write a code to access the value associated with the key "name" in the dictionary ('name': Alice', 'age: 30).

# %%
d3 = {"name": "Alice", "age": 30}
print(d3["name"])
# Out:
# Alice

# %% [markdown]
# 24. Write a code to remove the key 'age' from the dictionary ['name': 'Bob', 'age': 22, 'city: New York').

# %%
d4 = {"name": "Bob", "age": 22, "city": "New York"}
d4.pop("age")
print(d4)
# Out:
# {'name': 'Bob', 'city': 'New York'}

# %% [markdown]
# 25. Write a code to check if the key "city" exists in the dictionary ('name': 'Alice', 'city: Paris').

# %%
d5 = {"name": "Alice", "city": "Paris"}
print("city" in d5)
# Out:
# True

# %% [markdown]
# 26. Write a code to create a list, a tuple, and a dictionary, and print them all.

# %%
lst4 = [1, 2, 3]
t2 = (4, 5, 6)
d6 = {"x": 1, "y": 2}
print(lst4, t2, d6)
# Out:
# [1, 2, 3] (4, 5, 6) {'x': 1, 'y': 2}

# %% [markdown]
# 27. Write a code to create a list of 5 random numbers between 1 and 100, sort it in ascending order, and print the result (replaced)

# %%
import random
rand_list = random.sample(range(1, 101), 5)
rand_list.sort()
print(rand_list)
# Out:
# [10, 27, 32, 39, 74]

# %% [markdown]
# 28. Write a code to create a list with strings and print the element at the third index.

# %%
str_list = ["one", "two", "three", "four", "five"]
print(str_list[3])
# Out:
# four

# %% [markdown]
# 29. Write a code to combine two dictionaries into one and print the result.

# %%
d7 = {"a": 1, "b": 2}
d8 = {"c": 3, "d": 4}
d7.update(d8)
print(d7)
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %% [markdown]
# 30. Write a code to convert a list of strings into a set.

# %%
words = ["apple", "banana", "apple", "cherry"]
print(set(words))
# Out:
# {'cherry', 'apple', 'banana'}
